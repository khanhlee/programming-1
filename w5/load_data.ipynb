# %% [markdown]
# # Load data using Python

# %% [raw]
# https://www.kaggle.com/uciml/pima-indians-diabetes-database/data

# %% [markdown]
# ## Using CSV package

# %%
import csv

with open('pima-indians-diabetes.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\tPatient with {row[0]} pregnancty times and the glucose of {row[1]}.')
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are Pregnancy, Glucose, BloodPressure, Tricep, Insulin, BMI, DPF, Age, Diabetes
# 	Patient with 6 pregnancty times and the glucose of 148.
# 	Patient with 1 pregnancty times and the glucose of 85.
# 	Patient with 8 pregnancty times and the glucose of 183.
# 	Patient with 1 pregnancty times and the glucose of 89.
# 	Patient with 0 pregnancty times and the glucose of 137.
# 	Patient with 5 pregnancty times and the glucose of 116.
# 	Patient with 3 pregnancty times and the glucose of 78.
# 	Patient with 10 pregnancty times and the glucose of 115.
# 	Patient with 2 pregnancty times and the glucose of 197.
# 	Patient with 8 pregnancty times and the glucose of 125.
# 	Patient with 4 pregnancty times and the glucose of 110.
# 	Patient with 10 pregnancty times and the glucose of 168.
# 	Patient with 10 pregnancty times and the glucose of 139.
# 	Patient with 1 pregnancty times and the glucose of 189.
# 	Patient with 5 pregnancty times and the glucose of 166.
# ...

# %% [markdown]
# # Load CSV File With NumPy

# %%
raw_data = open('pima-indians-diabetes.csv')
data_new = np.loadtxt(raw_data, skiprows=1, delimiter=',')
data_new
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
data_new.shape
# Out:
# (768, 9)

# %% [markdown]
# # Load CSV File With Pandas

# %%
import pandas
data = pandas.read_csv(fileName)
data
# Out:
#      Pregnancy  Glucose  BloodPressure  Tricep  Insulin   BMI    DPF  Age  \
# 0            6      148             72      35        0  33.6  0.627   50
# 1            1       85             66      29        0  26.6  0.351   31
# 2            8      183             64       0        0  23.3  0.672   32
# 3            1       89             66      23       94  28.1  0.167   21
# 4            0      137             40      35      168  43.1  2.288   33
# ..         ...      ...            ...     ...      ...   ...    ...  ...
# 763         10      101             76      48      180  32.9  0.171   63
# 764          2      122             70      27        0  36.8  0.340   27
# 765          5      121             72      23      112  26.2  0.245   30
# 766          1      126             60       0        0  30.1  0.349   47
# 767          1       93             70      31        0  30.4  0.315   23
#
#      Diabetes
# 0           1
# 1           0
# 2           1
# 3           0
# ...

# %%
data.shape
# Out:
# (768, 9)

# %% [markdown]
# # Summarize data

# %%
data.head(20)
# Out:
#     Pregnancy  Glucose  BloodPressure  Tricep  Insulin   BMI    DPF  Age  \
# 0           6      148             72      35        0  33.6  0.627   50
# 1           1       85             66      29        0  26.6  0.351   31
# 2           8      183             64       0        0  23.3  0.672   32
# 3           1       89             66      23       94  28.1  0.167   21
# 4           0      137             40      35      168  43.1  2.288   33
# 5           5      116             74       0        0  25.6  0.201   30
# 6           3       78             50      32       88  31.0  0.248   26
# 7          10      115              0       0        0  35.3  0.134   29
# 8           2      197             70      45      543  30.5  0.158   53
# 9           8      125             96       0        0   0.0  0.232   54
# 10          4      110             92       0        0  37.6  0.191   30
# 11         10      168             74       0        0  38.0  0.537   34
# ...

# %%
data.shape
# Out:
# (768, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnancy        768 non-null int64
# Glucose          768 non-null int64
# BloodPressure    768 non-null int64
# Tricep           768 non-null int64
# Insulin          768 non-null int64
# BMI              768 non-null float64
# DPF              768 non-null float64
# Age              768 non-null int64
# Diabetes         768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#         Pregnancy     Glucose  BloodPressure      Tricep     Insulin  \
# count  768.000000  768.000000     768.000000  768.000000  768.000000
# mean     3.845052  120.894531      69.105469   20.536458   79.799479
# std      3.369578   31.972618      19.355807   15.952218  115.244002
# min      0.000000    0.000000       0.000000    0.000000    0.000000
# 25%      1.000000   99.000000      62.000000    0.000000    0.000000
# 50%      3.000000  117.000000      72.000000   23.000000   30.500000
# 75%      6.000000  140.250000      80.000000   32.000000  127.250000
# max     17.000000  199.000000     122.000000   99.000000  846.000000
#
#               BMI         DPF         Age    Diabetes
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
data.groupby('Age').size()
# Out:
# Age
# 21    63
# 22    72
# 23    38
# 24    46
# 25    48
# 26    33
# 27    32
# 28    35
# 29    29
# 30    21
# 31    24
# 32    16
# 33    17
# 34    14
# 35    10
# 36    16
# 37    19
# 38    16
# 39    12
# 40    13
# 41    22
# 42    18
# 43    13
# 44     8
# 45    15
# 46    13
# 47     6
# 48     5
# 49     5
# 50     8
# 51     8
# 52     8
# 53     5
# 54     6
# 55     4
# 56     3
# 57     5
# 58     7
# 59     3
# 60     5
# 61     2
# 62     4
# 63     4
# 64     1
# 65     3
# 66     4
# 67     3
# 68     1
# 69     2
# 70     1
# 72     1
# 81     1
# dtype: int64

# %% [markdown]
# # Univariate Plots

# %%
from pandas.plotting import scatter_matrix
from matplotlib import pyplot

# %%
data.plot(kind='box', color='r', subplots=True, layout=(3,3), figsize=(20,20))
pyplot.show()

# %%
data.hist(figsize=(20,20))
pyplot.show()

# %% [markdown]
# # Multivariate plot

# %%
scatter_matrix(data)
pyplot.show()

# %%
attributes = ['Age','BMI','Diabetes']
scatter_matrix(data[attributes])
pyplot.show()
